# %%
import numpy as np
from tensorflow import keras

# %%
from keras.datasets import mnist

#We import data into variables and check their shape.

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_train[:10]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4], dtype=uint8)

# %%
x_train_final = x_train.reshape((-1, 784))
x_train_final.shape
# Out:
# (60000, 784)

# %%
x_test_final = x_test.reshape((-1, 784))
x_test_final.shape
# Out:
# (10000, 784)

# %%
x_train_final = x_train_final / 255
x_test_final = x_test_final / 255

# %%
model = keras.Sequential(keras.layers.Dense(10, input_shape=(784,), activation='softmax'))

# %%
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
results = model.fit(
  x=x_train_final,
  y=y_train,
  shuffle=True,
  epochs=30,
  batch_size=16,
  validation_data=(x_test_final, y_test)

)
# Out:
# Epoch 1/30
# 3750/3750 [==============================] - 15s 3ms/step - loss: 0.6201 - accuracy: 0.8461 - val_loss: 0.3988 - val_accuracy: 0.8975
# Epoch 2/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.3915 - accuracy: 0.8934 - val_loss: 0.3486 - val_accuracy: 0.9053
# Epoch 3/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.3555 - accuracy: 0.9020 - val_loss: 0.3276 - val_accuracy: 0.9114
# Epoch 4/30
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.3371 - accuracy: 0.9058 - val_loss: 0.3158 - val_accuracy: 0.9131
# Epoch 5/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.3251 - accuracy: 0.9087 - val_loss: 0.3072 - val_accuracy: 0.9155
# Epoch 6/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.3166 - accuracy: 0.9115 - val_loss: 0.3007 - val_accuracy: 0.9188
# Epoch 7/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.3100 - accuracy: 0.9134 - val_loss: 0.2952 - val_accuracy: 0.9173
# Epoch 8/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.3048 - accuracy: 0.9151 - val_loss: 0.2919 - val_accuracy: 0.9187
# Epoch 9/30
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.3006 - accuracy: 0.9157 - val_loss: 0.2907 - val_accuracy: 0.9190
# Epoch 10/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2969 - accuracy: 0.9174 - val_loss: 0.2876 - val_accuracy: 0.9201
# Epoch 11/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2939 - accuracy: 0.9183 - val_loss: 0.2861 - val_accuracy: 0.9200
# Epoch 12/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2911 - accuracy: 0.9193 - val_loss: 0.2847 - val_accuracy: 0.9210
# Epoch 13/30
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.2888 - accuracy: 0.9198 - val_loss: 0.2822 - val_accuracy: 0.9206
# Epoch 14/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2867 - accuracy: 0.9204 - val_loss: 0.2811 - val_accuracy: 0.9214
# Epoch 15/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2847 - accuracy: 0.9208 - val_loss: 0.2808 - val_accuracy: 0.9212
# Epoch 16/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2831 - accuracy: 0.9213 - val_loss: 0.2792 - val_accuracy: 0.9216
# Epoch 17/30
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.2813 - accuracy: 0.9218 - val_loss: 0.2776 - val_accuracy: 0.9226
# Epoch 18/30
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.2799 - accuracy: 0.9224 - val_loss: 0.2779 - val_accuracy: 0.9211
# Epoch 19/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2786 - accuracy: 0.9227 - val_loss: 0.2774 - val_accuracy: 0.9228
# Epoch 20/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2772 - accuracy: 0.9230 - val_loss: 0.2760 - val_accuracy: 0.9225
# Epoch 21/30
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.2762 - accuracy: 0.9233 - val_loss: 0.2776 - val_accuracy: 0.9218
# Epoch 22/30
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.2752 - accuracy: 0.9236 - val_loss: 0.2753 - val_accuracy: 0.9227
# Epoch 23/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2741 - accuracy: 0.9246 - val_loss: 0.2761 - val_accuracy: 0.9217
# Epoch 24/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2730 - accuracy: 0.9247 - val_loss: 0.2736 - val_accuracy: 0.9220
# Epoch 25/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2723 - accuracy: 0.9244 - val_loss: 0.2731 - val_accuracy: 0.9224
# Epoch 26/30
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.2715 - accuracy: 0.9252 - val_loss: 0.2732 - val_accuracy: 0.9208
# Epoch 27/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2706 - accuracy: 0.9252 - val_loss: 0.2720 - val_accuracy: 0.9227
# Epoch 28/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2698 - accuracy: 0.9257 - val_loss: 0.2721 - val_accuracy: 0.9234
# Epoch 29/30
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2692 - accuracy: 0.9257 - val_loss: 0.2721 - val_accuracy: 0.9233
# Epoch 30/30
# 3750/3750 [==============================] - 12s 3ms/step - loss: 0.2684 - accuracy: 0.9261 - val_loss: 0.2712 - val_accuracy: 0.9225

# %%
eval = model.evaluate(x=x_test_final, y=y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2712 - accuracy: 0.9225

# %%
import matplotlib.pyplot as plt

plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.title('Training and Validation Losses')
plt.xlabel('epoch')
plt.ylabel('Losses')
# Out:
# Text(0, 0.5, 'Losses')

# %%
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.legend(['Training', 'Validation'])
plt.title('Training and Validation Losses')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
